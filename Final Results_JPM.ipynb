# %% [raw]
# Problem 1
# The following iterative sequence is defined for the set of positive integers:
# n → n/2 (n is even)
# n → 3n + 1 (n is odd)
# Using the rule above and starting with 13, we generate the following sequence:
# 13 → 40 → 20 → 10 → 5 → 16 → 8 → 4 → 2 → 1
# It can be seen that this sequence (starting at 13 and finishing at 1) contains 10 terms.
# Although it has not been proved yet (Collatz Problem), it is thought that all starting numbers finish at 1.
# a. Which starting number, under one million, produces the longest chain?
# b. Generalize the solution/program to accept an integer ‘n’ as input and provide the starting number under the integer ‘n’
# that produces the longest chain.
# NOTE: Once the chain starts the terms are allowed to go above one million. You can write a program in any language of
#     your choice to compute the answer. Share the program written via GitHub Link.

# %%
#Enter the number you want the sequence
start_num=13

# %%
#get the sequency and the count
a=0
def next_seq(num):
    if (num % 2 == 0):
        a=num / 2
    else:
        a= (3*num) +1
    return a

seq=[start_num]
next_num=start_num
count=1
if start_num > 1:
    while True:
        next_num=next_seq(next_num)
        seq.append(next_num)
        count=count+1
        if next_num==1:
            break

print("seq",seq)
print("count",count)
# Out:
# seq [13, 40, 20.0, 10.0, 5.0, 16.0, 8.0, 4.0, 2.0, 1.0]
# count 10

# %%
#to get the highest count for a number less than 1 million
count_nums=0
for i in range(13,1000000):
    seq=[i]
    next_num=i
    count=1
    if i > 1:
        while True:
            next_num=next_seq(next_num)
            seq.append(next_num)
            count=count+1
            if next_num==1:
                if count > count_nums:
                    count_nums=count
                    seq_final=seq
                break

print("count_nums:",count_nums)
print("Number which gives highest count:", seq_final[0])
print("seq_final",seq_final)
# Out:
# count_nums: 525
# Number which gives highest count: 837799
# ...

# %%
Problem 2

# %%
Problem 2
The Postal department of a country X, issues stamps. The denomination values of the stamps issued are 
in the respective currency value of 1, 2, 5, 10, 50 and 100 of the country X. Also each of the stamps 
can be issued in three different shapes which are Square Shape, Rectangle Shape and Triangular Shape. 
Plus, the country X has got 100 prominent National leaders and each of the stamp has got the face of one 
of the national leader embossed in it. A very curious stamp collector wants to create a collection, which
contains all the different possible stamps issued by the country X. The stamp collector is able to collect
one stamp at a time from the posts he receives, with each stamp being equally likely to show up on the post/envelope.

a. What is the expected number of Stamps required to be collected by the hobbyist so that he has a full collection?
b. How will you change your solution, if in the future the country adds more prominent National leaders to emboss list?

NOTE: You can write a program in any language of your choice to compute the answer. Share the program written via GitHub Link.

# %%
Currency values =[1,2,5,10,50,100]
so total no of differenty currencies = 6
Number of national leaders = 100
Different shapes of each curriency = 3

# %%
Tota_different_curriencies = 3*100*6 = 1800

# %%
Total number of stamps to be collected to have all the differnt stamps are =1800 ** 1800

# %%
Cur_Val=6
no_leader=100
cur_shape=3

# %%
total_no_stamp_col= (6*100*3) ** (6*100*3)

# %%
print("Total number of stamps to be collected", total_no_stamp_col)
# Out:
# Total number of stamps to be collected ...
